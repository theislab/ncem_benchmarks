# %%
# %load_ext autoreload
# %autoreload 2

import ncem

import matplotlib.pyplot as plt
import scanpy as sc
import numpy as np
from scipy.stats import ttest_rel, ttest_ind

usr = !echo $USER
grid_search_dir = '.'
datadir = '.'

# %%
gs_linear = ncem.train.GridSearchContainer(
    grid_search_dir, 
    gs_ids=[
        "211117_INTERACTIONS_BASELINE_PATIENT_JAROSCH",
        "211117b_INTERACTIONS_PATIENT_JAROSCH",
        
    ],
    lateral_resolution=0.5
)
gs_linear.load_gs()

gs_linear.summary_table = gs_linear.summary_table[
    gs_linear.summary_table['segmentation_robustness_node_fraction'] == 0.1]

gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="segmentation_robustness_overflow_fraction",
    param_hue="model",
    graph_model_class='interactions',
    baseline_model_class='interactions_baseline',
    #rename_levels = [
    #    ("model", {
    #        "INTERACTIONS_IMAGE": "linear",
    #        "INTERACTIONS_BASELINE_IMAGE": "baseline",
    #    })
    #],
    fontsize=14,
    rotate_xticks=False,
    figsize=(5.,4),
    yaxis_limit=(0.64, 0.76),
    #plot_mode = 'lineplot',
    #palette = {"baseline": "C0", "linear": "C1"},
    #xticks=[0, 5, 10, 30, 100],
    #save=savedir+"jarosch_segmentation_error_nf0.5_md5",
    #suffix=".pdf"
)
# Out:
# 211117_INTERACTIONS_BASELINE_PATIENT_JAROSCH: loaded 15 runs with 3-fold cross validation
# 211117b_INTERACTIONS_PATIENT_JAROSCH: loaded 116 runs with 3-fold cross validation
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.0
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.0
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.05
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.05
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.1
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.1
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.5
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.5
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.75
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.1_seof0.75

# %%
gs_linear = ncem.train.GridSearchContainer(
    grid_search_dir, 
    gs_ids=[
        "211117_INTERACTIONS_BASELINE_PATIENT_JAROSCH",
        "211117b_INTERACTIONS_PATIENT_JAROSCH",
        
    ],
    lateral_resolution=0.5
)
gs_linear.load_gs()

gs_linear.summary_table = gs_linear.summary_table[
    gs_linear.summary_table['segmentation_robustness_node_fraction'] == 0.5]

gs_linear.plot_best_model_by_hyperparam(
    partition_show="test",
    metric_show="r_squared_linreg",
    partition_select="val",
    metric_select="r_squared_linreg",
    param_x="segmentation_robustness_overflow_fraction",
    param_hue="model",
    graph_model_class='interactions',
    baseline_model_class='interactions_baseline',
    #rename_levels = [
    #    ("model", {
    #        "INTERACTIONS_IMAGE": "linear",
    #        "INTERACTIONS_BASELINE_IMAGE": "baseline",
    #    })
    #],
    fontsize=14,
    rotate_xticks=False,
    figsize=(5.,4),
    yaxis_limit=(0.64, 0.76),
    #plot_mode = 'lineplot',
    #palette = {"baseline": "C0", "linear": "C1"},
    #xticks=[0, 5, 10, 30, 100],
    #save=savedir+"jarosch_segmentation_error_nf0.5_md5",
    #suffix=".pdf"
)
# Out:
# 211117_INTERACTIONS_BASELINE_PATIENT_JAROSCH: loaded 15 runs with 3-fold cross validation
# 211117b_INTERACTIONS_PATIENT_JAROSCH: loaded 116 runs with 3-fold cross validation
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.0
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.0
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.05
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.05
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.1
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.1
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.5
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.5
# 211117_interactions_baseline_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.75
# 211117b_interactions_patient_jarosch_adam_lr1_bsS_md5_ri0_n100_fsstandard_l21_l11_senf0.5_seof0.75
